# %%
import pandas as pd
from tabulate import tabulate

# %%
data = pd.read_csv("train.csv", low_memory=False)

# %%
columnes_numeriques = data.select_dtypes(include=['number'])  # Selecciona columnes numèriques
columnes_categoriques = data.select_dtypes(exclude=['number'])  # Selecciona columnes no numèriques (categòriques)

# %%
columnes_numeriques.to_csv('columnes_numeriques.csv', index=False)
columnes_categoriques.to_csv('columnes_categoriques.csv', index=False)

# %%
columnes_numeriques.head()
# Out:
#                 Characteristics.LotFeatures  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  ['horses allowed', 'paddock', 'pond(s)']
#
#                      ImageData.features_reso.results  \
# 0  ['Cooling.CeilingFans', 'Flooring.Carpet', 'Fl...
# 1  ['Appliances.GasRange', 'Appliances.Range', 'A...
# 2  ['Flooring.Carpet', 'ParkingFeatures.Garage', ...
# 3  ['CommunityFeatures.Lake', 'WaterfrontFeatures...
# 4  ['Appliances.Refrigerator', 'Appliances.Microw...
#
#                     ImageData.room_type_reso.results  \
# 0  ['Other', 'FrontOfStructure', 'Basement', 'Sta...
# 1  ['SideOfStructure', 'Other', 'Kitchen', 'Office']
# 2  ['Community', 'FrontOfStructure', 'Other', 'Ga...
# 3                                   ['Yard', 'View']
# 4  ['FrontOfStructure', 'BackOfStructure', 'Commu...
#
#   ImageData.style.exterior.summary.label  \
# 0                                    NaN
# 1                                    NaN
# 2                               bungalow
# 3                                    NaN
# 4                                  ranch
#
#   ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 0                                   NaN     2023-12-22T00:00:00
# 1                                   NaN     2023-09-19T00:00:00
# 2                             2_stories     2023-12-04T00:00:00
# 3                                   NaN     2023-08-01T00:00:00
# 4                               1_story     2023-09-20T00:00:00
#
#   Listing.ListingId Location.Address.CensusBlock Location.Address.CensusTract  \
# 0       mrd09114306              17-195-300-1004                   17-195-300
# 1       mrd09478582            17-97-865400-2007                 17-97-865400
# 2       mrd09595738            17-31-210900-2014                 17-31-210900
# 3       mrd09604772                          NaN                          NaN
# 4       mrd09795957            17-89-852403-1029                 17-89-852403
#
#   Location.Address.City  ... Location.Area.SubdivisionName  \
# 0              morrison  ...                           NaN
# 1         highland park  ...                           NaN
# 2               chicago  ...                           NaN
# 3            wilmington  ...                           NaN
# 4            maple park  ...                           NaN
#
#   Location.School.HighSchoolDistrict Property.PropertyType Structure.Basement  \
# 0                                NaN       commercial sale                NaN
# 1                                112           residential        ['partial']
# 2                                NaN       commercial sale                NaN
# 3                               209u                  farm                NaN
# 4                                301           residential           ['full']
#
#           Structure.Cooling Structure.Heating Structure.NewConstructionYN  \
# 0           ['central air']               NaN                       False
# 1  ['window/wall unit - 1']   ['natural gas']                       False
# 2           ['central air']               NaN                       False
# 3                       NaN               NaN                       False
# 4       ['partial', 'none']         ['other']                       False
#
#       Structure.ParkingFeatures Tax.Zoning UnitTypes.UnitTypeType
# 0                           NaN      commr                    NaN
# 1                 ['off alley']        NaN                    NaN
# 2                           NaN      commr                    NaN
# 3                           NaN      agric                    NaN
# 4  ['unassigned', 'off street']        NaN                    NaN
#
# [5 rows x 31 columns]

# %%
columnes_categoriques.head()
# Out:
#                 Characteristics.LotFeatures  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  ['horses allowed', 'paddock', 'pond(s)']
#
#                      ImageData.features_reso.results  \
# 0  ['Cooling.CeilingFans', 'Flooring.Carpet', 'Fl...
# 1  ['Appliances.GasRange', 'Appliances.Range', 'A...
# 2  ['Flooring.Carpet', 'ParkingFeatures.Garage', ...
# 3  ['CommunityFeatures.Lake', 'WaterfrontFeatures...
# 4  ['Appliances.Refrigerator', 'Appliances.Microw...
#
#                     ImageData.room_type_reso.results  \
# 0  ['Other', 'FrontOfStructure', 'Basement', 'Sta...
# 1  ['SideOfStructure', 'Other', 'Kitchen', 'Office']
# 2  ['Community', 'FrontOfStructure', 'Other', 'Ga...
# 3                                   ['Yard', 'View']
# 4  ['FrontOfStructure', 'BackOfStructure', 'Commu...
#
#   ImageData.style.exterior.summary.label  \
# 0                                    NaN
# 1                                    NaN
# 2                               bungalow
# 3                                    NaN
# 4                                  ranch
#
#   ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 0                                   NaN     2023-12-22T00:00:00
# 1                                   NaN     2023-09-19T00:00:00
# 2                             2_stories     2023-12-04T00:00:00
# 3                                   NaN     2023-08-01T00:00:00
# 4                               1_story     2023-09-20T00:00:00
#
#   Listing.ListingId Location.Address.CensusBlock Location.Address.CensusTract  \
# 0       mrd09114306              17-195-300-1004                   17-195-300
# 1       mrd09478582            17-97-865400-2007                 17-97-865400
# 2       mrd09595738            17-31-210900-2014                 17-31-210900
# 3       mrd09604772                          NaN                          NaN
# 4       mrd09795957            17-89-852403-1029                 17-89-852403
#
#   Location.Address.City  ... Location.Area.SubdivisionName  \
# 0              morrison  ...                           NaN
# 1         highland park  ...                           NaN
# 2               chicago  ...                           NaN
# 3            wilmington  ...                           NaN
# 4            maple park  ...                           NaN
#
#   Location.School.HighSchoolDistrict Property.PropertyType Structure.Basement  \
# 0                                NaN       commercial sale                NaN
# 1                                112           residential        ['partial']
# 2                                NaN       commercial sale                NaN
# 3                               209u                  farm                NaN
# 4                                301           residential           ['full']
#
#           Structure.Cooling Structure.Heating Structure.NewConstructionYN  \
# 0           ['central air']               NaN                       False
# 1  ['window/wall unit - 1']   ['natural gas']                       False
# 2           ['central air']               NaN                       False
# 3                       NaN               NaN                       False
# 4       ['partial', 'none']         ['other']                       False
#
#       Structure.ParkingFeatures Tax.Zoning UnitTypes.UnitTypeType
# 0                           NaN      commr                    NaN
# 1                 ['off alley']        NaN                    NaN
# 2                           NaN      commr                    NaN
# 3                           NaN      agric                    NaN
# 4  ['unassigned', 'off street']        NaN                    NaN
#
# [5 rows x 31 columns]
