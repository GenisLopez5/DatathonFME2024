# %%
import pandas as pd
from tabulate import tabulate

# %%
data = pd.read_csv("train.csv", low_memory=False)
data.drop_duplicates()

# %%
print(tabulate(data.head(), headers='keys', tablefmt='psql'))
# Out:
# +----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+--------------------------------+--------------------------------+-------------------------+-----------------------------------+-------------------------------+------------------------------------+------------------------------------+------------------------------------------+------------------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------+------------------------------------------+---------------------------------+-------------------------+--------------------------+--------------------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------+
# |    | Characteristics.LotFeatures              |   Characteristics.LotSizeSquareFeet |   ImageData.c1c6.summary.bathroom |   ImageData.c1c6.summary.exterior |   ImageData.c1c6.summary.interior |   ImageData.c1c6.summary.kitchen |   ImageData.c1c6.summary.property | ImageData.features_reso.results                                                                                                                                                                                                                                                                                                                                                   |   ImageData.q1q6.summary.bathroom |   ImageData.q1q6.summary.exterior |   ImageData.q1q6.summary.interior |   ImageData.q1q6.summary.kitchen |   ImageData.q1q6.summary.property | ImageData.room_type_reso.results                                                                                                                      | ImageData.style.exterior.summary.label   | ImageData.style.stories.summary.label   | Listing.Dates.CloseDate   | Listing.ListingId   |   Listing.Price.ClosePrice | Location.Address.CensusBlock   | Location.Address.CensusTract   | Location.Address.City   | Location.Address.CountyOrParish   |   Location.Address.PostalCode |   Location.Address.PostalCodePlus4 | Location.Address.StateOrProvince   | Location.Address.StreetDirectionPrefix   |   Location.Address.StreetDirectionSuffix | Location.Address.StreetName   | Location.Address.StreetNumber   | Location.Address.StreetSuffix   |   Location.Address.UnitNumber | Location.Address.UnparsedAddress         |   Location.Area.SubdivisionName |   Location.GIS.Latitude |   Location.GIS.Longitude | Location.School.HighSchoolDistrict   | Property.PropertyType   | Structure.Basement   |   Structure.BathroomsFull |   Structure.BathroomsHalf |   Structure.BedroomsTotal |   Structure.BelowGradeFinishedArea |   Structure.BelowGradeUnfinishedArea | Structure.Cooling        |   Structure.FireplacesTotal |   Structure.GarageSpaces | Structure.Heating   |   Structure.LivingArea | Structure.NewConstructionYN   | Structure.ParkingFeatures    |   Structure.Rooms.RoomsTotal |   Structure.YearBuilt | Tax.Zoning   |   UnitTypes.UnitTypeType |
# |----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+--------------------------------+--------------------------------+-------------------------+-----------------------------------+-------------------------------+------------------------------------+------------------------------------+------------------------------------------+------------------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------+------------------------------------------+---------------------------------+-------------------------+--------------------------+--------------------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------|
# |  0 | nan                                      |                                3200 |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['Cooling.CeilingFans', 'Flooring.Carpet', 'Flooring.Tile', 'InteriorOrRoomFeatures.CeilingFans']                                                                                                                                                                                                                                                                                 |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Other', 'FrontOfStructure', 'Basement', 'Stairs', 'Bathroom']                                                                                       | nan                                      | nan                                     | 2023-12-22T00:00:00       | mrd09114306         |              30000         | 17-195-300-1004                | 17-195-300                     | morrison                | whiteside                         |                         61270 |                                nan | il                                 | e                                        |                                      nan | main                          | 126                             | street                          |                           nan | 126 e main street, morrison, il 61270    |                             nan |                -89.9663 |                  41.8092 | nan                                  | commercial sale         | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | ['central air']          |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                     0 | commr        |                      nan |
# |  1 | nan                                      |                                 nan |                               nan |                               3.8 |                               3.7 |                              3.8 |                               3.8 | ['Appliances.GasRange', 'Appliances.Range', 'Appliances.RangeHood', 'Appliances.Refrigerator', 'Cooling.WallWindowUnits', 'Cooling.WindowUnits', 'Flooring.Concrete', 'Flooring.Tile', 'Flooring.Carpet', 'Heating.Baseboard', 'Heating.Radiant', 'InteriorOrRoomFeatures.CrownMolding']                                                                                          |                               nan |                               4.2 |                                 4 |                                4 |                               4   | ['SideOfStructure', 'Other', 'Kitchen', 'Office']                                                                                                     | nan                                      | nan                                     | 2023-09-19T00:00:00       | mrd09478582         |             399000         | 17-97-865400-2007              | 17-97-865400                   | highland park           | lake                              |                         60035 |                                nan | il                                 | nan                                      |                                      nan | 1st                           | 1696                            | street                          |                           nan | 1696 1st street, highland park, il 60035 |                             nan |                -87.7985 |                  42.1837 | 112                                  | residential             | ['partial']          |                         2 |                         1 |                         1 |                                nan |                                  nan | ['window/wall unit - 1'] |                         nan |                      nan | ['natural gas']     |                   3175 | False                         | ['off alley']                |                            6 |                   nan | nan          |                      nan |
# |  2 | nan                                      |                               18750 |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['Flooring.Carpet', 'ParkingFeatures.Garage', 'PatioAndPorchFeatures.FrontPorch', 'PatioAndPorchFeatures.Porch']                                                                                                                                                                                                                                                                  |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Community', 'FrontOfStructure', 'Other', 'Garage', 'LivingRoom']                                                                                    | bungalow                                 | 2_stories                               | 2023-12-04T00:00:00       | mrd09595738         |                  2.05e+06  | 17-31-210900-2014              | 17-31-210900                   | chicago                 | cook                              |                         60618 |                                nan | il                                 | n                                        |                                      nan | elston                        | 2820                            | avenue                          |                           nan | 2820 n elston avenue, chicago, il 60618  |                             nan |                -87.6885 |                  41.9325 | nan                                  | commercial sale         | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | ['central air']          |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                  1926 | commr        |                      nan |
# |  3 | nan                                      |                                 nan |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['CommunityFeatures.Lake', 'WaterfrontFeatures.Lake']                                                                                                                                                                                                                                                                                                                             |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Yard', 'View']                                                                                                                                      | nan                                      | nan                                     | 2023-08-01T00:00:00       | mrd09604772         |             162000         | nan                            | nan                            | wilmington              | will                              |                         60481 |                                nan | il                                 | nan                                      |                                      nan | widows                        | lot 1                           | road                            |                           nan | lot 1 widows road, wilmington, il 60481  |                             nan |                nan      |                 nan      | 209u                                 | farm                    | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | nan                      |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                   nan | agric        |                      nan |
# |  4 | ['horses allowed', 'paddock', 'pond(s)'] |                                 nan |                               nan |                               3.6 |                             nan   |                            nan   |                               3.6 | ['Appliances.Refrigerator', 'Appliances.Microwave', 'Cooling.CeilingFans', 'ExteriorFeatures.Playground', 'Flooring.Tile', 'Flooring.Hardwood', 'InteriorOrRoomFeatures.CeilingFans', 'Levels.One', 'OtherStructures.Stables', 'OtherStructures.Garages', 'ParkingFeatures.Garage', 'ParkingFeatures.Detached', 'PatioAndPorchFeatures.Patio', 'SecurityFeatures.SmokeDetectors'] |                               nan |                               4.2 |                               nan |                              nan |                               4.2 | ['FrontOfStructure', 'BackOfStructure', 'Community', 'Other', 'Patio', 'Stable', 'Garage', 'OutBuildings', 'Yard', 'Playground', 'DiningArea', 'Bar'] | ranch                                    | 1_story                                 | 2023-09-20T00:00:00       | mrd09795957         |                  3.225e+06 | 17-89-852403-1029              | 17-89-852403                   | maple park              | kane                              |                         60151 |                                nan | il                                 | nan                                      |                                      nan | lees                          | 45w223                          | road                            |                           nan | 45w223 lees road, maple park, il 60151   |                             nan |                -88.4943 |                  41.9752 | 301                                  | residential             | ['full']             |                         1 |                         0 |                         2 |                                nan |                                  nan | ['partial', 'none']      |                         nan |                      nan | ['other']           |                      0 | False                         | ['unassigned', 'off street'] |                            4 |                  2006 | nan          |                      nan |
# +----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+--------------------------------+--------------------------------+-------------------------+-----------------------------------+-------------------------------+------------------------------------+------------------------------------+------------------------------------------+------------------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------+------------------------------------------+---------------------------------+-------------------------+--------------------------+--------------------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------+

# %%
# remove columns starting with 'Location.'
data = data.loc[:, ~data.columns.str.startswith('Location.')]
print(tabulate(data.head(), headers='keys', tablefmt='psql'))
# Out:
# +----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------+
# |    | Characteristics.LotFeatures              |   Characteristics.LotSizeSquareFeet |   ImageData.c1c6.summary.bathroom |   ImageData.c1c6.summary.exterior |   ImageData.c1c6.summary.interior |   ImageData.c1c6.summary.kitchen |   ImageData.c1c6.summary.property | ImageData.features_reso.results                                                                                                                                                                                                                                                                                                                                                   |   ImageData.q1q6.summary.bathroom |   ImageData.q1q6.summary.exterior |   ImageData.q1q6.summary.interior |   ImageData.q1q6.summary.kitchen |   ImageData.q1q6.summary.property | ImageData.room_type_reso.results                                                                                                                      | ImageData.style.exterior.summary.label   | ImageData.style.stories.summary.label   | Listing.Dates.CloseDate   | Listing.ListingId   |   Listing.Price.ClosePrice | Property.PropertyType   | Structure.Basement   |   Structure.BathroomsFull |   Structure.BathroomsHalf |   Structure.BedroomsTotal |   Structure.BelowGradeFinishedArea |   Structure.BelowGradeUnfinishedArea | Structure.Cooling        |   Structure.FireplacesTotal |   Structure.GarageSpaces | Structure.Heating   |   Structure.LivingArea | Structure.NewConstructionYN   | Structure.ParkingFeatures    |   Structure.Rooms.RoomsTotal |   Structure.YearBuilt | Tax.Zoning   |   UnitTypes.UnitTypeType |
# |----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------|
# |  0 | nan                                      |                                3200 |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['Cooling.CeilingFans', 'Flooring.Carpet', 'Flooring.Tile', 'InteriorOrRoomFeatures.CeilingFans']                                                                                                                                                                                                                                                                                 |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Other', 'FrontOfStructure', 'Basement', 'Stairs', 'Bathroom']                                                                                       | nan                                      | nan                                     | 2023-12-22T00:00:00       | mrd09114306         |              30000         | commercial sale         | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | ['central air']          |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                     0 | commr        |                      nan |
# |  1 | nan                                      |                                 nan |                               nan |                               3.8 |                               3.7 |                              3.8 |                               3.8 | ['Appliances.GasRange', 'Appliances.Range', 'Appliances.RangeHood', 'Appliances.Refrigerator', 'Cooling.WallWindowUnits', 'Cooling.WindowUnits', 'Flooring.Concrete', 'Flooring.Tile', 'Flooring.Carpet', 'Heating.Baseboard', 'Heating.Radiant', 'InteriorOrRoomFeatures.CrownMolding']                                                                                          |                               nan |                               4.2 |                                 4 |                                4 |                               4   | ['SideOfStructure', 'Other', 'Kitchen', 'Office']                                                                                                     | nan                                      | nan                                     | 2023-09-19T00:00:00       | mrd09478582         |             399000         | residential             | ['partial']          |                         2 |                         1 |                         1 |                                nan |                                  nan | ['window/wall unit - 1'] |                         nan |                      nan | ['natural gas']     |                   3175 | False                         | ['off alley']                |                            6 |                   nan | nan          |                      nan |
# |  2 | nan                                      |                               18750 |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['Flooring.Carpet', 'ParkingFeatures.Garage', 'PatioAndPorchFeatures.FrontPorch', 'PatioAndPorchFeatures.Porch']                                                                                                                                                                                                                                                                  |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Community', 'FrontOfStructure', 'Other', 'Garage', 'LivingRoom']                                                                                    | bungalow                                 | 2_stories                               | 2023-12-04T00:00:00       | mrd09595738         |                  2.05e+06  | commercial sale         | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | ['central air']          |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                  1926 | commr        |                      nan |
# |  3 | nan                                      |                                 nan |                               nan |                             nan   |                             nan   |                            nan   |                             nan   | ['CommunityFeatures.Lake', 'WaterfrontFeatures.Lake']                                                                                                                                                                                                                                                                                                                             |                               nan |                             nan   |                               nan |                              nan |                             nan   | ['Yard', 'View']                                                                                                                                      | nan                                      | nan                                     | 2023-08-01T00:00:00       | mrd09604772         |             162000         | farm                    | nan                  |                       nan |                       nan |                       nan |                                nan |                                  nan | nan                      |                         nan |                      nan | nan                 |                    nan | False                         | nan                          |                          nan |                   nan | agric        |                      nan |
# |  4 | ['horses allowed', 'paddock', 'pond(s)'] |                                 nan |                               nan |                               3.6 |                             nan   |                            nan   |                               3.6 | ['Appliances.Refrigerator', 'Appliances.Microwave', 'Cooling.CeilingFans', 'ExteriorFeatures.Playground', 'Flooring.Tile', 'Flooring.Hardwood', 'InteriorOrRoomFeatures.CeilingFans', 'Levels.One', 'OtherStructures.Stables', 'OtherStructures.Garages', 'ParkingFeatures.Garage', 'ParkingFeatures.Detached', 'PatioAndPorchFeatures.Patio', 'SecurityFeatures.SmokeDetectors'] |                               nan |                               4.2 |                               nan |                              nan |                               4.2 | ['FrontOfStructure', 'BackOfStructure', 'Community', 'Other', 'Patio', 'Stable', 'Garage', 'OutBuildings', 'Yard', 'Playground', 'DiningArea', 'Bar'] | ranch                                    | 1_story                                 | 2023-09-20T00:00:00       | mrd09795957         |                  3.225e+06 | residential             | ['full']             |                         1 |                         0 |                         2 |                                nan |                                  nan | ['partial', 'none']      |                         nan |                      nan | ['other']           |                      0 | False                         | ['unassigned', 'off street'] |                            4 |                  2006 | nan          |                      nan |
# +----+------------------------------------------+-------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-----------------------------------------+---------------------------+---------------------+----------------------------+-------------------------+----------------------+---------------------------+---------------------------+---------------------------+------------------------------------+--------------------------------------+--------------------------+-----------------------------+--------------------------+---------------------+------------------------+-------------------------------+------------------------------+------------------------------+-----------------------+--------------+--------------------------+
