# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import ast

# %%
# Load the data
data = pd.read_csv("train.csv", low_memory=False)
data.drop_duplicates() # remove duplicates

location = data.iloc[: , 19:36]
location
# Out:
#    Characteristics.LotFeatures  Characteristics.LotSizeSquareFeet  \
# 19                         NaN                           112700.0
# 20                         NaN                             5880.0
# 21                         NaN                            17300.0
# 22                         NaN                             5624.0
# 23                         NaN                                NaN
# 24                         NaN                                NaN
# 25                         NaN                                NaN
# 26                         NaN                                NaN
# 27                         NaN                            46173.0
# 28                         NaN                                NaN
# 29                         NaN                                NaN
# 30                         NaN                             7312.0
# 31                         NaN                                NaN
# ...
